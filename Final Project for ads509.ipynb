# %% [markdown]
# ## Necessary libraries and imports

# %%
# HTTP requests
import requests

# Data manipulation and analysis
import pandas as pd

# Numerical processing
import numpy as np

# Regular expressions for text processing
import re

# Natural Language Processing Toolkit
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Machine Learning
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD

# %%
import collections

# %%
import json
from urllib.parse import urlparse

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\micha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\micha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\micha\AppData\Roaming\nltk_data...
# True

# %%
pip install requests pandas numpy nltk scikit-learn pyLDAvis
# Out:
# Requirement already satisfied: requests in c:\users\micha\miniconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: pandas in c:\users\micha\miniconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy in c:\users\micha\miniconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: nltk in c:\users\micha\miniconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: scikit-learn in c:\users\micha\miniconda3\lib\site-packages (1.0.1)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\micha\miniconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micha\miniconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\micha\miniconda3\lib\site-packages (from requests) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\micha\miniconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\micha\miniconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\micha\miniconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\micha\miniconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\micha\miniconda3\lib\site-packages (from nltk) (4.61.2)
# Requirement already satisfied: click in c:\users\micha\miniconda3\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\micha\miniconda3\lib\site-packages (from nltk) (2023.5.5)
# Requirement already satisfied: joblib in c:\users\micha\miniconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\micha\miniconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\micha\miniconda3\lib\site-packages (from scikit-learn) (3.0.0)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: jinja2 in c:\users\micha\miniconda3\lib\site-packages (from pyLDAvis) (3.0.2)
# Collecting gensim
#   Using cached gensim-4.3.1-cp39-cp39-win_amd64.whl (24.0 MB)
# Requirement already satisfied: setuptools in c:\users\micha\miniconda3\lib\site-packages (from pyLDAvis) (52.0.0.post20210125)
# Collecting pandas
#   Using cached pandas-2.0.2-cp39-cp39-win_amd64.whl (10.7 MB)
# Requirement already satisfied: numexpr in c:\users\micha\miniconda3\lib\site-packages (from pyLDAvis) (2.7.3)
# Collecting funcy
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\micha\miniconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\micha\miniconda3\lib\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\micha\miniconda3\lib\site-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micha\miniconda3\lib\site-packages (from jinja2->pyLDAvis) (2.0.1)
# Installing collected packages: joblib, pandas, gensim, funcy, pyLDAvis
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
# Successfully installed funcy-2.0 gensim-4.3.1 joblib-1.2.0 pandas-2.0.2 pyLDAvis-3.4.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data Retrieval from PokeAPI(Pokemon Themselves)

# %% [markdown]
# ### Retrieval of pokemon names

# %%
# Putting in URL
url = 'https://pokeapi.co/api/v2/pokemon/1'

# Send GET request to PokeAPI
response = requests.get(url)

# Check that the request was successful
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# {'abilities': [{'ability': {'name': 'overgrow', 'url': 'https://pokeapi.co/api/v2/ability/65/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'chlorophyll', 'url': 'https://pokeapi.co/api/v2/ability/34/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 64, 'forms': [{'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}], 'game_indices': [{'game_index': 153, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 153, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 153, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 1, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 1, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 1, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 1, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'game_index': 1, 'version': {'name': 'sapphire', 'url': 'https://pokeapi.co/api/v2/version/8/'}}, {'game_index': 1, 'version': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version/9/'}}, {'game_index': 1, 'version': {'name': 'firered', 'url': 'https://pokeapi.co/api/v2/version/10/'}}, {'game_index': 1, 'version': {'name': 'leafgreen', 'url': 'https://pokeapi.co/api/v2/version/11/'}}, {'game_index': 1, 'version': {'name': 'diamond', 'url': 'https://pokeapi.co/api/v2/version/12/'}}, {'game_index': 1, 'version': {'name': 'pearl', 'url': 'https://pokeapi.co/api/v2/version/13/'}}, {'game_index': 1, 'version': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version/14/'}}, {'game_index': 1, 'version': {'name': 'heartgold', 'url': 'https://pokeapi.co/api/v2/version/15/'}}, {'game_index': 1, 'version': {'name': 'soulsilver', 'url': 'https://pokeapi.co/api/v2/version/16/'}}, {'game_index': 1, 'version': {'name': 'black', 'url': 'https://pokeapi.co/api/v2/version/17/'}}, {'game_index': 1, 'version': {'name': 'white', 'url': 'https://pokeapi.co/api/v2/version/18/'}}, {'game_index': 1, 'version': {'name': 'black-2', 'url': 'https://pokeapi.co/api/v2/version/21/'}}, {'game_index': 1, 'version': {'name': 'white-2', 'url': 'https://pokeapi.co/api/v2/version/22/'}}], 'height': 7, 'held_items': [], 'id': 1, 'is_default': True, 'location_area_encounters': 'https://pokeapi.co/api/v2/pokemon/1/encounters', 'moves': [{'move': {'name': 'razor-wind', 'url': 'https://pokeapi.co/api/v2/move/13/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'egg', 'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'}, 'version_group': {'name': 'gold-silver', 'url': 'https://pokeapi.co/api/v2/version-group/3/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'egg', 'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'}, 'version_group': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version-group/4/'}}]}, {'move': {'name': 'swords-dance', 'url': 'https://pokeapi.co/api/v2/move/14/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'red-blue', 'url': 'https://pokeapi.co/api/v2/version-group/1/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version-group/2/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version-group/6/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'firered-leafgreen', 'url': 'https://pokeapi.co/api/v2/version-group/7/'}}, {'level_le ...

# %% [markdown]
# ## Data Cleaning, Tokenization, and Normalization

# %%
if response.status_code == 200:
    data = response.json()
    #Cleaning: Remove URL fields
    def clean_data(data):
        for key in list(data.keys()):
            if type(data[key]) is dict:
                clean_data(data[key])
            elif type(data[key]) is list:
                for item in data[key]:
                    if type(item) is dict:
                        clean_data(item)
            elif 'url' in key:
                del data[key]

    clean_data(data)

    # Tokenization: Flatten data
    def tokenize_data(data, prefix=''):
        tokens = []
        for key in data:
            if isinstance(data[key], dict):
                tokens.extend(tokenize_data(data[key], f'{prefix}{key}_'))
            elif isinstance(data[key], list):
                for i, item in enumerate(data[key]):
                    if isinstance(item, dict):
                        tokens.extend(tokenize_data(item, f'{prefix}{key}_{i}_'))
                    else:
                        tokens.append((f'{prefix}{key}_{i}', item))
            else:
                tokens.append((f'{prefix}{key}', data[key]))
        return tokens

    tokens = tokenize_data(data)

    # Normalization: Tokens to lowercase and remove special characters
    def normalize_tokens(tokens):
        normalized_tokens = []
        for key, value in tokens:
            key = key.lower().replace('-', '_')
            value = str(value).lower().replace('-', '_')
            normalized_tokens.append((key, value))
        return normalized_tokens

    normalized_tokens = normalize_tokens(tokens)

    print(json.dumps(normalized_tokens, indent=2))

else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# [
#   [
#     "abilities_0_ability_name",
#     "pressure"
#   ],
#   [
#     "abilities_0_is_hidden",
#     "false"
#   ],
#   [
#     "abilities_0_slot",
#     "1"
#   ],
#   [
#     "abilities_1_ability_name",
#     "unnerve"
#   ],
#   [
#     "abilities_1_is_hidden",
#     "true"
#   ],
#   [
#     "abilities_1_slot",
#     "3"
#   ],
#   [
#     "base_experience",
#     "340"
#   ],
#   [
#     "forms_0_name",
#     "mewtwo"
#   ],
#   [
#     "game_indices_0_game_index",
#     "131"
#   ],
#   [
#     "game_indices_0_version_name",
#     "red"
#   ],
#   [
#     "game_indices_1_game_index",
#     "131"
#   ],
#   [
#     "game_indices_1_version_name",
#     "blue"
#   ],
#   [
#     "game_indices_2_game_index",
#     "131"
#   ],
#   [
#     "game_indices_2_version_name",
#     "yellow"
#   ],
#   [
#     "game_indices_3_game_index",
#     "150"
#   ],
#   [
#     "game_indices_3_version_name",
#     "gold"
#   ],
#   [
#     "game_indices_4_game_index",
#     "150"
#   ],
#   [
#     "game_indices_4_version_name",
#     "silver"
#   ],
#   [
#     "game_indices_5_game_index",
#     "150"
#   ],
#   [
#     "game_indices_5_version_name",
#     "crystal"
#   ],
#   [
#     "game_indices_6_game_index",
#     "150"
#   ],
#   [
#     "game_indices_6_version_name",
#     "ruby"
#   ],
#   [
#     "game_indices_7_game_index",
#     "150"
#   ],
#   [
#     "game_indices_7_version_name",
#     "sapphire"
#   ],
#   [
#     "game_indices_8_game_index",
#     "150"
#   ],
#   [
#     "game_indices_8_version_name",
#     "emerald"
#   ],
#   [
#     "game_indices_9_game_index",
#     "150"
#   ],
#   [
#     "game_indices_9_version_name",
#     "firered"
#   ],
#   [
#     "game_indices_10_game_index",
#     "150"
#   ],
#   [
#     "game_indices_10_version_name",
#     "leafgreen"
#   ],
#   [
#     "game_indices_11_game_index",
#     "150"
#   ],
#   [
#     "game_indices_11_version_name",
#     "diamond"
#   ],
#   [
#     "game_indices_12_game_index",
#     "150"
#   ],
#   [
#     "game_indices_12_version_name",
#     "pearl"
#   ],
#   [
#     "game_indices_13_game_index",
#     "150"
#   ],
#   [
#     "game_indices_13_version_name",
#     "platinum"
#   ],
#   [
#     "game_indices_14_game_index",
#     "150"
#   ],
#   [
#     "game_indices_14_version_name",
#     "heartgold"
#   ],
#   [
#     "game_indices_15_game_index",
#     "150"
#   ],
#   [
#     "game_indices_15_version_name",
#     "soulsilver"
#   ],
#   [
#     "game_indices_16_game_index",
#     "150"
#   ],
#   [
#     "game_indices_16_version_name",
#     "black"
#   ],
#   [
#     "game_indices_17_game_index",
#     "150"
#   ],
#   [
#     "game_indices_17_version_name",
#     "white"
#   ],
#   [
#     "game_indices_18_game_index",
#     "150"
#   ],
#   [
#     "game_indices_18_version_name",
#     "black_2"
#   ],
#   [
#     "game_indices_19_game_index",
#     "150"
#   ],
#   [
#     "game_indices_19_version_name",
#     "white_2"
#   ],
#   [
#     "height",
#     "20"
#   ],
#   [
#     "id",
#     "150"
#   ],
#   [
#     "is_default",
#     "true"
#   ],
#   [
#     "location_area_encounters",
#     "https://pokeapi.co/api/v2/pokemon/150/encounters"
#   ],
#   [
#     "moves_0_move_name",
#     "mega_punch"
#   ],
#   [
#     "moves_0_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_0_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_0_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_0_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_0_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_0_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_0_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_0_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_0_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_0_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_0_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_0_version_group_details_3_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_0_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_0_version_group_details_4_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_0_version_group_details_4_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_1_move_name",
#     "pay_day"
#   ],
#   [
#     "moves_1_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_1_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_1_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_1_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_1_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_1_version_group_details_1_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_1_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_1_version_group_details_2_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_1_version_group_details_2_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_2_move_name",
#     "fire_punch"
#   ],
#   [
#     "moves_2_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_2_version_group_details_0_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_2_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_2_version_group_details_1_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_2_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_2_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_2_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_2_version_group_details_3_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_2_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_4_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_2_version_group_details_4_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_2_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_5_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_2_version_group_details_5_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_2_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_6_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_2_version_group_details_6_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_2_version_group_details_7_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_7_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_2_version_group_details_7_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_2_version_group_details_8_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_8_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_2_version_group_details_8_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_2_version_group_details_9_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_9_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_2_version_group_details_9_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_2_version_group_details_10_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_2_version_group_details_10_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_2_version_group_details_10_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_3_move_name",
#     "ice_punch"
#   ],
#   [
#     "moves_3_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_3_version_group_details_0_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_3_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_3_version_group_details_1_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_3_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_3_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_3_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_3_version_group_details_3_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_3_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_4_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_3_version_group_details_4_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_3_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_5_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_3_version_group_details_5_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_3_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_6_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_3_version_group_details_6_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_3_version_group_details_7_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_7_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_3_version_group_details_7_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_3_version_group_details_8_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_8_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_3_version_group_details_8_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_3_version_group_details_9_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_9_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_3_version_group_details_9_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_3_version_group_details_10_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_3_version_group_details_10_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_3_version_group_details_10_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_4_move_name",
#     "thunder_punch"
#   ],
#   [
#     "moves_4_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_4_version_group_details_0_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_4_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_4_version_group_details_1_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_4_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_4_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_4_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_4_version_group_details_3_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_4_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_4_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_4_version_group_details_4_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_4_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_5_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_4_version_group_details_5_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_4_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_6_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_4_version_group_details_6_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_4_version_group_details_7_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_7_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_4_version_group_details_7_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_4_version_group_details_8_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_8_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_4_version_group_details_8_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_4_version_group_details_9_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_9_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_4_version_group_details_9_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_4_version_group_details_10_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_4_version_group_details_10_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_4_version_group_details_10_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_5_move_name",
#     "mega_kick"
#   ],
#   [
#     "moves_5_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_5_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_5_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_5_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_5_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_5_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_5_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_5_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_5_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_5_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_5_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_5_version_group_details_3_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_5_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_5_version_group_details_4_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_5_version_group_details_4_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_6_move_name",
#     "headbutt"
#   ],
#   [
#     "moves_6_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_6_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_6_version_group_details_0_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_6_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_6_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_6_version_group_details_1_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_6_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_6_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_6_version_group_details_2_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_6_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_6_version_group_details_3_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_6_version_group_details_3_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_7_move_name",
#     "body_slam"
#   ],
#   [
#     "moves_7_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_7_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_7_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_7_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_7_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_7_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_7_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_7_version_group_details_3_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_7_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_4_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_7_version_group_details_4_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_7_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_5_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_7_version_group_details_5_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_7_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_7_version_group_details_6_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_7_version_group_details_6_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_8_move_name",
#     "take_down"
#   ],
#   [
#     "moves_8_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_8_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_8_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_8_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_8_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_8_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_8_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_8_version_group_details_2_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_8_version_group_details_2_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_9_move_name",
#     "double_edge"
#   ],
#   [
#     "moves_9_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_9_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_9_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_9_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_9_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_9_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_9_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_9_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_9_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_9_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_9_version_group_details_3_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_9_version_group_details_3_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_9_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_9_version_group_details_4_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_9_version_group_details_4_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_10_move_name",
#     "disable"
#   ],
#   [
#     "moves_10_version_group_details_0_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_0_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_10_version_group_details_1_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_1_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_10_version_group_details_2_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_2_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_2_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_10_version_group_details_3_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_3_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_3_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_10_version_group_details_4_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_4_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_4_version_group_name",
#     "ruby_sapphire"
#   ],
#   [
#     "moves_10_version_group_details_5_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_5_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_5_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_10_version_group_details_6_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_6_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_6_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_10_version_group_details_7_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_7_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_7_version_group_name",
#     "diamond_pearl"
#   ],
#   [
#     "moves_10_version_group_details_8_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_8_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_8_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_10_version_group_details_9_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_9_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_9_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_10_version_group_details_10_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_10_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_10_version_group_name",
#     "black_white"
#   ],
#   [
#     "moves_10_version_group_details_11_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_11_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_11_version_group_name",
#     "colosseum"
#   ],
#   [
#     "moves_10_version_group_details_12_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_12_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_12_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_10_version_group_details_13_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_13_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_13_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_10_version_group_details_14_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_14_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_14_version_group_name",
#     "x_y"
#   ],
#   [
#     "moves_10_version_group_details_15_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_15_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_15_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_10_version_group_details_16_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_16_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_16_version_group_name",
#     "sun_moon"
#   ],
#   [
#     "moves_10_version_group_details_17_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_17_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_17_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_10_version_group_details_18_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_18_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_18_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_10_version_group_details_19_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_19_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_19_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_10_version_group_details_20_level_learned_at",
#     "1"
#   ],
#   [
#     "moves_10_version_group_details_20_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_10_version_group_details_20_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_11_move_name",
#     "flamethrower"
#   ],
#   [
#     "moves_11_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_0_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_11_version_group_details_0_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_11_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_1_version_group_name",
#     "ruby_sapphire"
#   ],
#   [
#     "moves_11_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_2_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_2_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_11_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_3_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_3_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_11_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_4_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_4_version_group_name",
#     "diamond_pearl"
#   ],
#   [
#     "moves_11_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_5_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_5_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_11_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_6_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_6_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_11_version_group_details_7_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_7_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_7_version_group_name",
#     "black_white"
#   ],
#   [
#     "moves_11_version_group_details_8_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_8_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_8_version_group_name",
#     "colosseum"
#   ],
#   [
#     "moves_11_version_group_details_9_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_9_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_9_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_11_version_group_details_10_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_10_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_10_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_11_version_group_details_11_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_11_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_11_version_group_name",
#     "x_y"
#   ],
#   [
#     "moves_11_version_group_details_12_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_12_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_12_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_11_version_group_details_13_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_13_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_13_version_group_name",
#     "sun_moon"
#   ],
#   [
#     "moves_11_version_group_details_14_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_14_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_14_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_11_version_group_details_15_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_15_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_15_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_11_version_group_details_16_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_16_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_16_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_11_version_group_details_17_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_11_version_group_details_17_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_11_version_group_details_17_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_12_move_name",
#     "mist"
#   ],
#   [
#     "moves_12_version_group_details_0_level_learned_at",
#     "75"
#   ],
#   [
#     "moves_12_version_group_details_0_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_12_version_group_details_1_level_learned_at",
#     "75"
#   ],
#   [
#     "moves_12_version_group_details_1_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_12_version_group_details_2_level_learned_at",
#     "55"
#   ],
#   [
#     "moves_12_version_group_details_2_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_2_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_12_version_group_details_3_level_learned_at",
#     "55"
#   ],
#   [
#     "moves_12_version_group_details_3_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_3_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_12_version_group_details_4_level_learned_at",
#     "55"
#   ],
#   [
#     "moves_12_version_group_details_4_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_4_version_group_name",
#     "ruby_sapphire"
#   ],
#   [
#     "moves_12_version_group_details_5_level_learned_at",
#     "55"
#   ],
#   [
#     "moves_12_version_group_details_5_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_5_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_12_version_group_details_6_level_learned_at",
#     "22"
#   ],
#   [
#     "moves_12_version_group_details_6_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_6_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_12_version_group_details_7_level_learned_at",
#     "43"
#   ],
#   [
#     "moves_12_version_group_details_7_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_7_version_group_name",
#     "diamond_pearl"
#   ],
#   [
#     "moves_12_version_group_details_8_level_learned_at",
#     "43"
#   ],
#   [
#     "moves_12_version_group_details_8_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_8_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_12_version_group_details_9_level_learned_at",
#     "43"
#   ],
#   [
#     "moves_12_version_group_details_9_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_9_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_12_version_group_details_10_level_learned_at",
#     "36"
#   ],
#   [
#     "moves_12_version_group_details_10_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_10_version_group_name",
#     "black_white"
#   ],
#   [
#     "moves_12_version_group_details_11_level_learned_at",
#     "55"
#   ],
#   [
#     "moves_12_version_group_details_11_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_11_version_group_name",
#     "colosseum"
#   ],
#   [
#     "moves_12_version_group_details_12_level_learned_at",
#     "55"
#   ],
#   [
#     "moves_12_version_group_details_12_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_12_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_12_version_group_details_13_level_learned_at",
#     "36"
#   ],
#   [
#     "moves_12_version_group_details_13_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_13_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_12_version_group_details_14_level_learned_at",
#     "86"
#   ],
#   [
#     "moves_12_version_group_details_14_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_14_version_group_name",
#     "x_y"
#   ],
#   [
#     "moves_12_version_group_details_15_level_learned_at",
#     "86"
#   ],
#   [
#     "moves_12_version_group_details_15_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_15_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_12_version_group_details_16_level_learned_at",
#     "86"
#   ],
#   [
#     "moves_12_version_group_details_16_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_16_version_group_name",
#     "sun_moon"
#   ],
#   [
#     "moves_12_version_group_details_17_level_learned_at",
#     "86"
#   ],
#   [
#     "moves_12_version_group_details_17_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_17_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_12_version_group_details_18_level_learned_at",
#     "11"
#   ],
#   [
#     "moves_12_version_group_details_18_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_18_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_12_version_group_details_19_level_learned_at",
#     "64"
#   ],
#   [
#     "moves_12_version_group_details_19_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_19_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_12_version_group_details_20_level_learned_at",
#     "64"
#   ],
#   [
#     "moves_12_version_group_details_20_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_12_version_group_details_20_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_13_move_name",
#     "water_gun"
#   ],
#   [
#     "moves_13_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_13_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_13_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_13_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_13_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_13_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_14_move_name",
#     "ice_beam"
#   ],
#   [
#     "moves_14_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_14_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_14_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_2_move_learn_method_name",
#     "tutor"
#   ],
#   [
#     "moves_14_version_group_details_2_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_14_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_3_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_3_version_group_name",
#     "ruby_sapphire"
#   ],
#   [
#     "moves_14_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_4_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_4_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_14_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_5_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_5_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_14_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_6_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_6_version_group_name",
#     "diamond_pearl"
#   ],
#   [
#     "moves_14_version_group_details_7_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_7_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_7_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_14_version_group_details_8_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_8_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_8_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_14_version_group_details_9_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_9_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_9_version_group_name",
#     "black_white"
#   ],
#   [
#     "moves_14_version_group_details_10_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_10_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_10_version_group_name",
#     "colosseum"
#   ],
#   [
#     "moves_14_version_group_details_11_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_11_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_11_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_14_version_group_details_12_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_12_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_12_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_14_version_group_details_13_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_13_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_13_version_group_name",
#     "x_y"
#   ],
#   [
#     "moves_14_version_group_details_14_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_14_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_14_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_14_version_group_details_15_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_15_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_15_version_group_name",
#     "sun_moon"
#   ],
#   [
#     "moves_14_version_group_details_16_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_16_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_16_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_14_version_group_details_17_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_17_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_17_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_14_version_group_details_18_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_18_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_18_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_14_version_group_details_19_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_14_version_group_details_19_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_14_version_group_details_19_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_15_move_name",
#     "blizzard"
#   ],
#   [
#     "moves_15_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_15_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_15_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_2_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_2_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_15_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_3_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_3_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_15_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_4_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_4_version_group_name",
#     "ruby_sapphire"
#   ],
#   [
#     "moves_15_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_5_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_5_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_15_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_6_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_6_version_group_name",
#     "firered_leafgreen"
#   ],
#   [
#     "moves_15_version_group_details_7_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_7_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_7_version_group_name",
#     "diamond_pearl"
#   ],
#   [
#     "moves_15_version_group_details_8_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_8_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_8_version_group_name",
#     "platinum"
#   ],
#   [
#     "moves_15_version_group_details_9_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_9_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_9_version_group_name",
#     "heartgold_soulsilver"
#   ],
#   [
#     "moves_15_version_group_details_10_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_10_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_10_version_group_name",
#     "black_white"
#   ],
#   [
#     "moves_15_version_group_details_11_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_11_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_11_version_group_name",
#     "colosseum"
#   ],
#   [
#     "moves_15_version_group_details_12_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_12_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_12_version_group_name",
#     "xd"
#   ],
#   [
#     "moves_15_version_group_details_13_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_13_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_13_version_group_name",
#     "black_2_white_2"
#   ],
#   [
#     "moves_15_version_group_details_14_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_14_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_14_version_group_name",
#     "x_y"
#   ],
#   [
#     "moves_15_version_group_details_15_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_15_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_15_version_group_name",
#     "omega_ruby_alpha_sapphire"
#   ],
#   [
#     "moves_15_version_group_details_16_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_16_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_16_version_group_name",
#     "sun_moon"
#   ],
#   [
#     "moves_15_version_group_details_17_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_17_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_17_version_group_name",
#     "ultra_sun_ultra_moon"
#   ],
#   [
#     "moves_15_version_group_details_18_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_18_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_18_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_15_version_group_details_19_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_19_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_19_version_group_name",
#     "sword_shield"
#   ],
#   [
#     "moves_15_version_group_details_20_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_15_version_group_details_20_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_15_version_group_details_20_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_16_move_name",
#     "psybeam"
#   ],
#   [
#     "moves_16_version_group_details_0_level_learned_at",
#     "22"
#   ],
#   [
#     "moves_16_version_group_details_0_move_learn_method_name",
#     "level_up"
#   ],
#   [
#     "moves_16_version_group_details_0_version_group_name",
#     "lets_go_pikachu_lets_go_eevee"
#   ],
#   [
#     "moves_16_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_16_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_16_version_group_details_1_version_group_name",
#     "scarlet_violet"
#   ],
#   [
#     "moves_17_move_name",
#     "bubble_beam"
#   ],
#   [
#     "moves_17_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_17_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_17_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_17_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_17_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_17_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_18_move_name",
#     "hyper_beam"
#   ],
#   [
#     "moves_18_version_group_details_0_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_0_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_0_version_group_name",
#     "red_blue"
#   ],
#   [
#     "moves_18_version_group_details_1_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_1_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_1_version_group_name",
#     "yellow"
#   ],
#   [
#     "moves_18_version_group_details_2_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_2_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_2_version_group_name",
#     "gold_silver"
#   ],
#   [
#     "moves_18_version_group_details_3_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_3_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_3_version_group_name",
#     "crystal"
#   ],
#   [
#     "moves_18_version_group_details_4_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_4_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_4_version_group_name",
#     "ruby_sapphire"
#   ],
#   [
#     "moves_18_version_group_details_5_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_5_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_5_version_group_name",
#     "emerald"
#   ],
#   [
#     "moves_18_version_group_details_6_level_learned_at",
#     "0"
#   ],
#   [
#     "moves_18_version_group_details_6_move_learn_method_name",
#     "machine"
#   ],
#   [
#     "moves_18_version_group_details_6_version_group_name",
# ...
#   [
#     "sprites_versions_generation_i_red_blue_front_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/red_blue/transparent/150.png"
#   ],
#   [
#     "sprites_versions_generation_i_yellow_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/yellow/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_i_yellow_back_gray",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/yellow/back/gray/150.png"
#   ],
#   [
#     "sprites_versions_generation_i_yellow_back_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/yellow/transparent/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_i_yellow_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/yellow/150.png"
#   ],
#   [
#     "sprites_versions_generation_i_yellow_front_gray",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/yellow/gray/150.png"
#   ],
#   [
#     "sprites_versions_generation_i_yellow_front_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_i/yellow/transparent/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_back_shiny_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/transparent/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_back_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/transparent/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_front_shiny_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/transparent/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_crystal_front_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/crystal/transparent/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_gold_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/gold/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_gold_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/gold/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_gold_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/gold/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_gold_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/gold/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_gold_front_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/gold/transparent/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_silver_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/silver/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_silver_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/silver/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_silver_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/silver/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_silver_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/silver/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_ii_silver_front_transparent",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_ii/silver/transparent/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_emerald_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/emerald/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_emerald_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/emerald/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_firered_leafgreen_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/firered_leafgreen/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_firered_leafgreen_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/firered_leafgreen/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_firered_leafgreen_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/firered_leafgreen/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_firered_leafgreen_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/firered_leafgreen/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_ruby_sapphire_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/ruby_sapphire/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_ruby_sapphire_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/ruby_sapphire/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_ruby_sapphire_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/ruby_sapphire/150.png"
#   ],
#   [
#     "sprites_versions_generation_iii_ruby_sapphire_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iii/ruby_sapphire/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/diamond_pearl/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_back_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/diamond_pearl/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_back_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/diamond_pearl/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/diamond_pearl/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_diamond_pearl_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/heartgold_soulsilver/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_back_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/heartgold_soulsilver/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_back_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/heartgold_soulsilver/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/heartgold_soulsilver/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_heartgold_soulsilver_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/platinum/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_back_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/platinum/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_back_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/platinum/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_iv/platinum/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_iv_platinum_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/animated/back/150.gif"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_back_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/animated/back/shiny/150.gif"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_back_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/animated/150.gif"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/animated/shiny/150.gif"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_animated_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_back_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/back/150.png"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_back_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_back_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/back/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_back_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/150.png"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_v/black_white/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_v_black_white_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vi_omegaruby_alphasapphire_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vi/omegaruby_alphasapphire/150.png"
#   ],
#   [
#     "sprites_versions_generation_vi_omegaruby_alphasapphire_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vi_omegaruby_alphasapphire_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vi/omegaruby_alphasapphire/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_vi_omegaruby_alphasapphire_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vi_x_y_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vi/x_y/150.png"
#   ],
#   [
#     "sprites_versions_generation_vi_x_y_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vi_x_y_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vi/x_y/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_vi_x_y_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vii_icons_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vii/icons/150.png"
#   ],
#   [
#     "sprites_versions_generation_vii_icons_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vii_ultra_sun_ultra_moon_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vii/ultra_sun_ultra_moon/150.png"
#   ],
#   [
#     "sprites_versions_generation_vii_ultra_sun_ultra_moon_front_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_vii_ultra_sun_ultra_moon_front_shiny",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_vii/ultra_sun_ultra_moon/shiny/150.png"
#   ],
#   [
#     "sprites_versions_generation_vii_ultra_sun_ultra_moon_front_shiny_female",
#     "none"
#   ],
#   [
#     "sprites_versions_generation_viii_icons_front_default",
#     "https://raw.githubusercontent.com/pokeapi/sprites/master/sprites/pokemon/versions/generation_viii/icons/150.png"
#   ],
#   [
#     "sprites_versions_generation_viii_icons_front_female",
#     "none"
#   ],
#   [
#     "stats_0_base_stat",
#     "106"
#   ],
#   [
#     "stats_0_effort",
#     "0"
#   ],
#   [
#     "stats_0_stat_name",
#     "hp"
#   ],
#   [
#     "stats_1_base_stat",
#     "110"
#   ],
#   [
#     "stats_1_effort",
#     "0"
#   ],
#   [
#     "stats_1_stat_name",
#     "attack"
#   ],
#   [
#     "stats_2_base_stat",
#     "90"
#   ],
#   [
#     "stats_2_effort",
#     "0"
#   ],
#   [
#     "stats_2_stat_name",
#     "defense"
#   ],
#   [
#     "stats_3_base_stat",
#     "154"
#   ],
#   [
#     "stats_3_effort",
#     "3"
#   ],
#   [
#     "stats_3_stat_name",
#     "special_attack"
#   ],
#   [
#     "stats_4_base_stat",
#     "90"
#   ],
#   [
#     "stats_4_effort",
#     "0"
#   ],
#   [
#     "stats_4_stat_name",
#     "special_defense"
#   ],
#   [
#     "stats_5_base_stat",
#     "130"
#   ],
#   [
#     "stats_5_effort",
#     "0"
#   ],
#   [
#     "stats_5_stat_name",
#     "speed"
#   ],
#   [
#     "types_0_slot",
#     "1"
#   ],
#   [
#     "types_0_type_name",
#     "psychic"
#   ],
#   [
#     "weight",
#     "1220"
#   ]
# ]

# %%
#Testing it out
print(data['name'])  # Prints the name of the Pokémon
print(data['height'])  # Prints the height of the Pokémon
# Out:
# bulbasaur
# 7

# %% [markdown]
# ### retrieval for items, moves and abilities

# %%
# URLs of items, moves, and abilities
item_url = 'https://pokeapi.co/api/v2/item'
move_url = 'https://pokeapi.co/api/v2/move'
ability_url = 'https://pokeapi.co/api/v2/ability'

item_response = requests.get(item_url)
move_response = requests.get(move_url)
ability_response = requests.get(ability_url)

if item_response.status_code == 200:
    item_data = item_response.json()
    print(item_data)
else:
    print(f"Item request failed with status code {item_response.status_code}")

if move_response.status_code == 200:
    move_data = move_response.json()
    print(move_data)
else:
    print(f"Move request failed with status code {move_response.status_code}")

if ability_response.status_code == 200:
    ability_data = ability_response.json()
    print(ability_data)
else:
    print(f"Ability request failed with status code {ability_response.status_code}")
# Out:
# {'count': 2050, 'next': 'https://pokeapi.co/api/v2/item?offset=20&limit=20', 'previous': None, 'results': [{'name': 'master-ball', 'url': 'https://pokeapi.co/api/v2/item/1/'}, {'name': 'ultra-ball', 'url': 'https://pokeapi.co/api/v2/item/2/'}, {'name': 'great-ball', 'url': 'https://pokeapi.co/api/v2/item/3/'}, {'name': 'poke-ball', 'url': 'https://pokeapi.co/api/v2/item/4/'}, {'name': 'safari-ball', 'url': 'https://pokeapi.co/api/v2/item/5/'}, {'name': 'net-ball', 'url': 'https://pokeapi.co/api/v2/item/6/'}, {'name': 'dive-ball', 'url': 'https://pokeapi.co/api/v2/item/7/'}, {'name': 'nest-ball', 'url': 'https://pokeapi.co/api/v2/item/8/'}, {'name': 'repeat-ball', 'url': 'https://pokeapi.co/api/v2/item/9/'}, {'name': 'timer-ball', 'url': 'https://pokeapi.co/api/v2/item/10/'}, {'name': 'luxury-ball', 'url': 'https://pokeapi.co/api/v2/item/11/'}, {'name': 'premier-ball', 'url': 'https://pokeapi.co/api/v2/item/12/'}, {'name': 'dusk-ball', 'url': 'https://pokeapi.co/api/v2/item/13/'}, {'name': 'heal-ball', 'url': 'https://pokeapi.co/api/v2/item/14/'}, {'name': 'quick-ball', 'url': 'https://pokeapi.co/api/v2/item/15/'}, {'name': 'cherish-ball', 'url': 'https://pokeapi.co/api/v2/item/16/'}, {'name': 'potion', 'url': 'https://pokeapi.co/api/v2/item/17/'}, {'name': 'antidote', 'url': 'https://pokeapi.co/api/v2/item/18/'}, {'name': 'burn-heal', 'url': 'https://pokeapi.co/api/v2/item/19/'}, {'name': 'ice-heal', 'url': 'https://pokeapi.co/api/v2/item/20/'}]}
# {'count': 918, 'next': 'https://pokeapi.co/api/v2/move?offset=20&limit=20', 'previous': None, 'results': [{'name': 'pound', 'url': 'https://pokeapi.co/api/v2/move/1/'}, {'name': 'karate-chop', 'url': 'https://pokeapi.co/api/v2/move/2/'}, {'name': 'double-slap', 'url': 'https://pokeapi.co/api/v2/move/3/'}, {'name': 'comet-punch', 'url': 'https://pokeapi.co/api/v2/move/4/'}, {'name': 'mega-punch', 'url': 'https://pokeapi.co/api/v2/move/5/'}, {'name': 'pay-day', 'url': 'https://pokeapi.co/api/v2/move/6/'}, {'name': 'fire-punch', 'url': 'https://pokeapi.co/api/v2/move/7/'}, {'name': 'ice-punch', 'url': 'https://pokeapi.co/api/v2/move/8/'}, {'name': 'thunder-punch', 'url': 'https://pokeapi.co/api/v2/move/9/'}, {'name': 'scratch', 'url': 'https://pokeapi.co/api/v2/move/10/'}, {'name': 'vice-grip', 'url': 'https://pokeapi.co/api/v2/move/11/'}, {'name': 'guillotine', 'url': 'https://pokeapi.co/api/v2/move/12/'}, {'name': 'razor-wind', 'url': 'https://pokeapi.co/api/v2/move/13/'}, {'name': 'swords-dance', 'url': 'https://pokeapi.co/api/v2/move/14/'}, {'name': 'cut', 'url': 'https://pokeapi.co/api/v2/move/15/'}, {'name': 'gust', 'url': 'https://pokeapi.co/api/v2/move/16/'}, {'name': 'wing-attack', 'url': 'https://pokeapi.co/api/v2/move/17/'}, {'name': 'whirlwind', 'url': 'https://pokeapi.co/api/v2/move/18/'}, {'name': 'fly', 'url': 'https://pokeapi.co/api/v2/move/19/'}, {'name': 'bind', 'url': 'https://pokeapi.co/api/v2/move/20/'}]}
# {'count': 358, 'next': 'https://pokeapi.co/api/v2/ability?offset=20&limit=20', 'previous': None, 'results': [{'name': 'stench', 'url': 'https://pokeapi.co/api/v2/ability/1/'}, {'name': 'drizzle', 'url': 'https://pokeapi.co/api/v2/ability/2/'}, {'name': 'speed-boost', 'url': 'https://pokeapi.co/api/v2/ability/3/'}, {'name': 'battle-armor', 'url': 'https://pokeapi.co/api/v2/ability/4/'}, {'name': 'sturdy', 'url': 'https://pokeapi.co/api/v2/ability/5/'}, {'name': 'damp', 'url': 'https://pokeapi.co/api/v2/ability/6/'}, {'name': 'limber', 'url': 'https://pokeapi.co/api/v2/ability/7/'}, {'name': 'sand-veil', 'url': 'https://pokeapi.co/api/v2/ability/8/'}, {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, {'name': 'volt-absorb', 'url': 'https://pokeapi.co/api/v2/ability/10/'}, {'name': 'water-absorb', 'url': 'https://pokeapi.co/api/v2/ability/11/'}, {'name': 'oblivious', 'url': 'https://pokeapi.co/api/v2/ability/12/'}, {'name': 'cloud-nine', 'url': 'https://pokeapi.co/api/v2/ability/13/'}, {'name': 'compound-eyes', 'url': 'https://pokeapi.co/api/v2/ability/14/'}, {'name': 'insomnia', 'url': 'https://pokeapi.co/api/v2/ability/15/'}, {'name': 'color-change', 'url': 'https://pokeapi.co/api/v2/ability/16/'}, {'name': 'immunity', 'url': 'https://pokeapi.co/api/v2/ability/17/'}, {'name': 'flash-fire', 'url': 'https://pokeapi.co/api/v2/ability/18/'}, {'name': 'shield-dust', 'url': 'https://pokeapi.co/api/v2/ability/19/'}, {'name': 'own-tempo', 'url': 'https://pokeapi.co/api/v2/ability/20/'}]}

# %%
item_names = [result['name'] for result in item_data['results']]
move_names = [result['name'] for result in move_data['results']]
ability_names = [result['name'] for result in ability_data['results']]

# %% [markdown]
# ## Descriptive stats

# %% [markdown]
# ### Descriptive Stats for Pokemon

# %%
# Lists to hold base experience and weight data
base_exp_data = []
weight_data = []

# Base experience and weight for first 150 Pokémon
for i in range(1, 151):
    url = f'https://pokeapi.co/api/v2/pokemon/{i}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        clean_data(data)
        tokens = tokenize_data(data)
        normalized_tokens = normalize_tokens(tokens)
        # Convert normalized tokens to dictionary
        token_dict = dict(normalized_tokens)
        base_exp_data.append(int(token_dict['base_experience']))
        weight_data.append(int(token_dict['weight']))
    else:
        print(f'Request failed for Pokémon ID {i} with status code {response.status_code}')

# Convert lists to pandas DataFrame
df = pd.DataFrame({'Base Experience': base_exp_data, 'Weight': weight_data})

# Descriptive statistics
print(df.describe())
# Out:
#        Base Experience       Weight
# count       150.000000   150.000000
# mean        137.486667   462.313333
# std          72.590488   595.473881
# min          39.000000     1.000000
# 25%          65.000000    99.250000
# 50%         142.000000   300.000000
# 75%         175.000000   563.750000
# max         395.000000  4600.000000

# %% [markdown]
# ### Descriptive Stats for Items, Movves, and Ablities

# %%
item_counts = collections.Counter(item_names)
move_counts = collections.Counter(move_names)
ability_counts = collections.Counter(ability_names)

# Print counts
print("Item counts:", item_counts)
print("Move counts:", move_counts)
print("Ability counts:", ability_counts)
# Out:
# Item counts: Counter({'master-ball': 1, 'ultra-ball': 1, 'great-ball': 1, 'poke-ball': 1, 'safari-ball': 1, 'net-ball': 1, 'dive-ball': 1, 'nest-ball': 1, 'repeat-ball': 1, 'timer-ball': 1, 'luxury-ball': 1, 'premier-ball': 1, 'dusk-ball': 1, 'heal-ball': 1, 'quick-ball': 1, 'cherish-ball': 1, 'potion': 1, 'antidote': 1, 'burn-heal': 1, 'ice-heal': 1})
# Move counts: Counter({'pound': 1, 'karate-chop': 1, 'double-slap': 1, 'comet-punch': 1, 'mega-punch': 1, 'pay-day': 1, 'fire-punch': 1, 'ice-punch': 1, 'thunder-punch': 1, 'scratch': 1, 'vice-grip': 1, 'guillotine': 1, 'razor-wind': 1, 'swords-dance': 1, 'cut': 1, 'gust': 1, 'wing-attack': 1, 'whirlwind': 1, 'fly': 1, 'bind': 1})
# Ability counts: Counter({'stench': 1, 'drizzle': 1, 'speed-boost': 1, 'battle-armor': 1, 'sturdy': 1, 'damp': 1, 'limber': 1, 'sand-veil': 1, 'static': 1, 'volt-absorb': 1, 'water-absorb': 1, 'oblivious': 1, 'cloud-nine': 1, 'compound-eyes': 1, 'insomnia': 1, 'color-change': 1, 'immunity': 1, 'flash-fire': 1, 'shield-dust': 1, 'own-tempo': 1})

# %%
# Number of uniques for each
print("Number of unique items:", len(set(item_names)))
print("Number of unique moves:", len(set(move_names)))
print("Number of unique abilities:", len(set(ability_names)))
# Out:
# Number of unique items: 20
# Number of unique moves: 20
# Number of unique abilities: 20

# %%
# Common name
print("Most common item:", item_counts.most_common(1))
print("Most common move:", move_counts.most_common(1))
print("Most common ability:", ability_counts.most_common(1))
# Out:
# Most common item: [('master-ball', 1)]
# Most common move: [('pound', 1)]
# Most common ability: [('stench', 1)]

# %%
# Proportion of each category
item_total = sum(item_counts.values())
item_proportions = {k: v / item_total for k, v in item_counts.items()}

move_total = sum(move_counts.values())
move_proportions = {k: v / move_total for k, v in move_counts.items()}

ability_total = sum(ability_counts.values())
ability_proportions = {k: v / ability_total for k, v in ability_counts.items()}

print("Item proportions:", item_proportions)
print("Move proportions:", move_proportions)
print("Ability proportions:", ability_proportions)
# Out:
# Item proportions: {'master-ball': 0.05, 'ultra-ball': 0.05, 'great-ball': 0.05, 'poke-ball': 0.05, 'safari-ball': 0.05, 'net-ball': 0.05, 'dive-ball': 0.05, 'nest-ball': 0.05, 'repeat-ball': 0.05, 'timer-ball': 0.05, 'luxury-ball': 0.05, 'premier-ball': 0.05, 'dusk-ball': 0.05, 'heal-ball': 0.05, 'quick-ball': 0.05, 'cherish-ball': 0.05, 'potion': 0.05, 'antidote': 0.05, 'burn-heal': 0.05, 'ice-heal': 0.05}
# Move proportions: {'pound': 0.05, 'karate-chop': 0.05, 'double-slap': 0.05, 'comet-punch': 0.05, 'mega-punch': 0.05, 'pay-day': 0.05, 'fire-punch': 0.05, 'ice-punch': 0.05, 'thunder-punch': 0.05, 'scratch': 0.05, 'vice-grip': 0.05, 'guillotine': 0.05, 'razor-wind': 0.05, 'swords-dance': 0.05, 'cut': 0.05, 'gust': 0.05, 'wing-attack': 0.05, 'whirlwind': 0.05, 'fly': 0.05, 'bind': 0.05}
# Ability proportions: {'stench': 0.05, 'drizzle': 0.05, 'speed-boost': 0.05, 'battle-armor': 0.05, 'sturdy': 0.05, 'damp': 0.05, 'limber': 0.05, 'sand-veil': 0.05, 'static': 0.05, 'volt-absorb': 0.05, 'water-absorb': 0.05, 'oblivious': 0.05, 'cloud-nine': 0.05, 'compound-eyes': 0.05, 'insomnia': 0.05, 'color-change': 0.05, 'immunity': 0.05, 'flash-fire': 0.05, 'shield-dust': 0.05, 'own-tempo': 0.05}

# %%
# Sorting categories by frequencies
sorted_item_counts = sorted(item_counts.items(), key=lambda x: x[1], reverse=True)
sorted_move_counts = sorted(move_counts.items(), key=lambda x: x[1], reverse=True)
sorted_ability_counts = sorted(ability_counts.items(), key=lambda x: x[1], reverse=True)

print("Items sorted by count:", sorted_item_counts)
print("Moves sorted by count:", sorted_move_counts)
print("Abilities sorted by count:", sorted_ability_counts)
# Out:
# Items sorted by count: [('master-ball', 1), ('ultra-ball', 1), ('great-ball', 1), ('poke-ball', 1), ('safari-ball', 1), ('net-ball', 1), ('dive-ball', 1), ('nest-ball', 1), ('repeat-ball', 1), ('timer-ball', 1), ('luxury-ball', 1), ('premier-ball', 1), ('dusk-ball', 1), ('heal-ball', 1), ('quick-ball', 1), ('cherish-ball', 1), ('potion', 1), ('antidote', 1), ('burn-heal', 1), ('ice-heal', 1)]
# Moves sorted by count: [('pound', 1), ('karate-chop', 1), ('double-slap', 1), ('comet-punch', 1), ('mega-punch', 1), ('pay-day', 1), ('fire-punch', 1), ('ice-punch', 1), ('thunder-punch', 1), ('scratch', 1), ('vice-grip', 1), ('guillotine', 1), ('razor-wind', 1), ('swords-dance', 1), ('cut', 1), ('gust', 1), ('wing-attack', 1), ('whirlwind', 1), ('fly', 1), ('bind', 1)]
# Abilities sorted by count: [('stench', 1), ('drizzle', 1), ('speed-boost', 1), ('battle-armor', 1), ('sturdy', 1), ('damp', 1), ('limber', 1), ('sand-veil', 1), ('static', 1), ('volt-absorb', 1), ('water-absorb', 1), ('oblivious', 1), ('cloud-nine', 1), ('compound-eyes', 1), ('insomnia', 1), ('color-change', 1), ('immunity', 1), ('flash-fire', 1), ('shield-dust', 1), ('own-tempo', 1)]

# %%
# Checking for specific categories
specific_item = 'poke-ball'
specific_move = 'tackle'
specific_ability = 'overgrow'

print(f"Count of {specific_item}:", item_counts[specific_item])
print(f"Count of {specific_move}:", move_counts[specific_move])
print(f"Count of {specific_ability}:", ability_counts[specific_ability])
# Out:
# Count of poke-ball: 1
# Count of tackle: 0
# Count of overgrow: 0
