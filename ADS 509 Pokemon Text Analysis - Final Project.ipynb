# %% [markdown]
# # ADS 509 Pokemon Text Analysis: Final Project
# ### Imports

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from flask import Flask, render_template, url_for, request
import joblib
import json
from collections import Counter
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### Read in the text file

# %%
f = open('C:/Users/mendi/Desktop/USD Class Files/ADS 509/Pokemon_Data.txt')
data = json.load(f)
print(len(data))
# Out:
# 1281

# %% [markdown]
# ### Functions & Tokenize

# %%
# Removing URL's
def remove_URL(text):
    return re.sub(r"'url ' : 'http\S+", "", text)

# Tokenize the data
def tokenize(text) :
    return(word_tokenize(text))

# Applying the pipeline
def prepare(text, pipeline) :
    tokens = str(text)
    for transform in pipeline :
        tokens = transform(tokens)
    return(tokens)

# Descriptive statistics of the data
def descriptive_stats(tokens, num_words = 5, verbose=True) :
    num_tokens = len(tokens)
    num_unique_tokens = len(Counter(tokens).keys())
    lexical_diversity = round((num_unique_tokens/num_tokens),2) # Rounded to 2 Digits to match format of existing decimal rounding below
    num_characters = sum(len(i) for i in tokens)
    countered = Counter(tokens)
    if verbose :        
        print(f"There are {num_tokens} tokens in the data.")
        print(f"There are {num_unique_tokens} unique tokens in the data.")
        print(f"There are {num_characters} characters in the data.")
        print(f"The lexical diversity is {lexical_diversity:.3f} in the data.")        
    return

# %%
pokemon_list = []
p_list = []
for pokemon in data:
    for features in data[pokemon]:
        #print(a) # a is the whole section of combined features
        for feature, description in features.items():
            # b is the dictionaries such as ability, weight, stats that are pulled
            #print(c) # Farthest I can break down for now.
            #p_list.append()
            poke_dict = {'pokemon': pokemon, 'feature': feature, 'description': description}
            pokemon_list.append(poke_dict)

# %%
df = pd.DataFrame.from_dict(pokemon_list)
df
# Out:
#                    pokemon          feature  \
# 0                bulbasaur        abilities
# 1                bulbasaur  base_experience
# 2                bulbasaur            forms
# 3                bulbasaur     game_indices
# 4                bulbasaur           height
# ...                    ...              ...
# 23053  miraidon-glide-mode          species
# 23054  miraidon-glide-mode          sprites
# 23055  miraidon-glide-mode            stats
# 23056  miraidon-glide-mode            types
# 23057  miraidon-glide-mode           weight
#
#                                              description
# 0      [{'ability': {'name': 'overgrow', 'url': 'http...
# 1                                                     64
# 2      [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 3      [{'game_index': 153, 'version': {'name': 'red'...
# 4                                                      7
# ...                                                  ...
# 23053  {'name': 'miraidon', 'url': 'https://pokeapi.c...
# 23054  {'back_default': None, 'back_female': None, 'b...
# 23055  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 23056  [{'slot': 1, 'type': {'name': 'electric', 'url...
# 23057                                               2400
#
# [23058 rows x 3 columns]

# %%
my_pipeline = [str.lower,remove_URL,tokenize]
cleaned_data = []
for row in pokemon_list :
    text = " ".join(prepare(row, pipeline = my_pipeline))
    if text :
        cleaned_data.append(text)

# %% [markdown]
# ### Descriptive Statistics

# %%
descriptive_stats(cleaned_data)
# Out:
# There are 23058 tokens in the data.
# There are 23058 unique tokens in the data.
# There are 169063470 characters in the data.
# The lexical diversity is 1.000 in the data.

# %%
descriptive_stats(df)
# Out:
# There are 23058 tokens in the data.
# There are 3 unique tokens in the data.
# There are 25 characters in the data.
# The lexical diversity is 0.000 in the data.

# %% [markdown]
# ### Feature Engineering

# %%
transposed_data = df.pivot(columns='feature',values='description')
transposed_data.head()
# Out:
# feature                                          abilities base_experience  \
# 0        [{'ability': {'name': 'overgrow', 'url': 'http...             NaN
# 1                                                      NaN              64
# 2                                                      NaN             NaN
# 3                                                      NaN             NaN
# 4                                                      NaN             NaN
#
# feature                                              forms  \
# 0                                                      NaN
# 1                                                      NaN
# 2        [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 3                                                      NaN
# 4                                                      NaN
#
# feature                                       game_indices height held_items  \
# 0                                                      NaN    NaN        NaN
# 1                                                      NaN    NaN        NaN
# 2                                                      NaN    NaN        NaN
# 3        [{'game_index': 153, 'version': {'name': 'red'...    NaN        NaN
# 4                                                      NaN      7        NaN
#
# feature   id is_default location_area_encounters moves name order past_types  \
# 0        NaN        NaN                      NaN   NaN  NaN   NaN        NaN
# 1        NaN        NaN                      NaN   NaN  NaN   NaN        NaN
# 2        NaN        NaN                      NaN   NaN  NaN   NaN        NaN
# 3        NaN        NaN                      NaN   NaN  NaN   NaN        NaN
# 4        NaN        NaN                      NaN   NaN  NaN   NaN        NaN
#
# feature species sprites stats types weight
# 0           NaN     NaN   NaN   NaN    NaN
# 1           NaN     NaN   NaN   NaN    NaN
# 2           NaN     NaN   NaN   NaN    NaN
# 3           NaN     NaN   NaN   NaN    NaN
# 4           NaN     NaN   NaN   NaN    NaN

# %%
transposed_datad = transposed_data.drop(columns = ['held_items', 'id', 'is_default', 'order', 
                                        'past_types', 'location_area_encounters', 'sprites',
                                       'forms', 'species'])
transposed_datad.head(50)
# Out:
# feature                                          abilities base_experience  \
# 0        [{'ability': {'name': 'overgrow', 'url': 'http...             NaN
# 1                                                      NaN              64
# 2                                                      NaN             NaN
# 3                                                      NaN             NaN
# 4                                                      NaN             NaN
# 5                                                      NaN             NaN
# 6                                                      NaN             NaN
# 7                                                      NaN             NaN
# 8                                                      NaN             NaN
# 9                                                      NaN             NaN
# 10                                                     NaN             NaN
# 11                                                     NaN             NaN
# 12                                                     NaN             NaN
# 13                                                     NaN             NaN
# 14                                                     NaN             NaN
# 15                                                     NaN             NaN
# 16                                                     NaN             NaN
# 17                                                     NaN             NaN
# 18       [{'ability': {'name': 'overgrow', 'url': 'http...             NaN
# 19                                                     NaN             142
# 20                                                     NaN             NaN
# 21                                                     NaN             NaN
# 22                                                     NaN             NaN
# 23                                                     NaN             NaN
# 24                                                     NaN             NaN
# 25                                                     NaN             NaN
# 26                                                     NaN             NaN
# 27                                                     NaN             NaN
# 28                                                     NaN             NaN
# 29                                                     NaN             NaN
# 30                                                     NaN             NaN
# 31                                                     NaN             NaN
# 32                                                     NaN             NaN
# 33                                                     NaN             NaN
# 34                                                     NaN             NaN
# 35                                                     NaN             NaN
# 36       [{'ability': {'name': 'overgrow', 'url': 'http...             NaN
# 37                                                     NaN             263
# 38                                                     NaN             NaN
# 39                                                     NaN             NaN
# 40                                                     NaN             NaN
# 41                                                     NaN             NaN
# 42                                                     NaN             NaN
# 43                                                     NaN             NaN
# 44                                                     NaN             NaN
# 45                                                     NaN             NaN
# 46                                                     NaN             NaN
# 47                                                     NaN             NaN
# 48                                                     NaN             NaN
# 49                                                     NaN             NaN
#
# feature                                       game_indices height  \
# 0                                                      NaN    NaN
# 1                                                      NaN    NaN
# 2                                                      NaN    NaN
# 3        [{'game_index': 153, 'version': {'name': 'red'...    NaN
# 4                                                      NaN      7
# 5                                                      NaN    NaN
# 6                                                      NaN    NaN
# 7                                                      NaN    NaN
# 8                                                      NaN    NaN
# 9                                                      NaN    NaN
# 10                                                     NaN    NaN
# 11                                                     NaN    NaN
# 12                                                     NaN    NaN
# 13                                                     NaN    NaN
# 14                                                     NaN    NaN
# 15                                                     NaN    NaN
# 16                                                     NaN    NaN
# 17                                                     NaN    NaN
# 18                                                     NaN    NaN
# 19                                                     NaN    NaN
# 20                                                     NaN    NaN
# 21       [{'game_index': 9, 'version': {'name': 'red', ...    NaN
# 22                                                     NaN     10
# 23                                                     NaN    NaN
# 24                                                     NaN    NaN
# 25                                                     NaN    NaN
# 26                                                     NaN    NaN
# 27                                                     NaN    NaN
# 28                                                     NaN    NaN
# 29                                                     NaN    NaN
# 30                                                     NaN    NaN
# 31                                                     NaN    NaN
# 32                                                     NaN    NaN
# 33                                                     NaN    NaN
# 34                                                     NaN    NaN
# 35                                                     NaN    NaN
# 36                                                     NaN    NaN
# 37                                                     NaN    NaN
# 38                                                     NaN    NaN
# 39       [{'game_index': 154, 'version': {'name': 'red'...    NaN
# 40                                                     NaN     20
# 41                                                     NaN    NaN
# 42                                                     NaN    NaN
# 43                                                     NaN    NaN
# 44                                                     NaN    NaN
# 45                                                     NaN    NaN
# 46                                                     NaN    NaN
# 47                                                     NaN    NaN
# 48                                                     NaN    NaN
# 49                                                     NaN    NaN
#
# feature                                              moves       name  \
# 0                                                      NaN        NaN
# 1                                                      NaN        NaN
# 2                                                      NaN        NaN
# 3                                                      NaN        NaN
# 4                                                      NaN        NaN
# 5                                                      NaN        NaN
# 6                                                      NaN        NaN
# 7                                                      NaN        NaN
# 8                                                      NaN        NaN
# 9        [{'move': {'name': 'razor-wind', 'url': 'https...        NaN
# 10                                                     NaN  bulbasaur
# 11                                                     NaN        NaN
# 12                                                     NaN        NaN
# 13                                                     NaN        NaN
# 14                                                     NaN        NaN
# 15                                                     NaN        NaN
# 16                                                     NaN        NaN
# 17                                                     NaN        NaN
# 18                                                     NaN        NaN
# 19                                                     NaN        NaN
# 20                                                     NaN        NaN
# 21                                                     NaN        NaN
# 22                                                     NaN        NaN
# 23                                                     NaN        NaN
# 24                                                     NaN        NaN
# 25                                                     NaN        NaN
# 26                                                     NaN        NaN
# 27       [{'move': {'name': 'swords-dance', 'url': 'htt...        NaN
# 28                                                     NaN    ivysaur
# 29                                                     NaN        NaN
# 30                                                     NaN        NaN
# 31                                                     NaN        NaN
# 32                                                     NaN        NaN
# 33                                                     NaN        NaN
# 34                                                     NaN        NaN
# 35                                                     NaN        NaN
# 36                                                     NaN        NaN
# 37                                                     NaN        NaN
# 38                                                     NaN        NaN
# 39                                                     NaN        NaN
# 40                                                     NaN        NaN
# 41                                                     NaN        NaN
# 42                                                     NaN        NaN
# 43                                                     NaN        NaN
# 44                                                     NaN        NaN
# 45       [{'move': {'name': 'swords-dance', 'url': 'htt...        NaN
# 46                                                     NaN   venusaur
# 47                                                     NaN        NaN
# 48                                                     NaN        NaN
# 49                                                     NaN        NaN
#
# feature                                              stats  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15       [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# 30                                                     NaN
# 31                                                     NaN
# 32                                                     NaN
# 33       [{'base_stat': 60, 'effort': 0, 'stat': {'name...
# 34                                                     NaN
# 35                                                     NaN
# 36                                                     NaN
# 37                                                     NaN
# 38                                                     NaN
# 39                                                     NaN
# 40                                                     NaN
# 41                                                     NaN
# 42                                                     NaN
# 43                                                     NaN
# 44                                                     NaN
# 45                                                     NaN
# 46                                                     NaN
# 47                                                     NaN
# 48                                                     NaN
# 49                                                     NaN
#
# feature                                              types weight
# 0                                                      NaN    NaN
# 1                                                      NaN    NaN
# 2                                                      NaN    NaN
# 3                                                      NaN    NaN
# 4                                                      NaN    NaN
# 5                                                      NaN    NaN
# 6                                                      NaN    NaN
# 7                                                      NaN    NaN
# 8                                                      NaN    NaN
# 9                                                      NaN    NaN
# 10                                                     NaN    NaN
# 11                                                     NaN    NaN
# 12                                                     NaN    NaN
# 13                                                     NaN    NaN
# 14                                                     NaN    NaN
# 15                                                     NaN    NaN
# 16       [{'slot': 1, 'type': {'name': 'grass', 'url': ...    NaN
# 17                                                     NaN     69
# 18                                                     NaN    NaN
# 19                                                     NaN    NaN
# 20                                                     NaN    NaN
# 21                                                     NaN    NaN
# 22                                                     NaN    NaN
# 23                                                     NaN    NaN
# 24                                                     NaN    NaN
# 25                                                     NaN    NaN
# 26                                                     NaN    NaN
# 27                                                     NaN    NaN
# 28                                                     NaN    NaN
# 29                                                     NaN    NaN
# 30                                                     NaN    NaN
# 31                                                     NaN    NaN
# 32                                                     NaN    NaN
# 33                                                     NaN    NaN
# 34       [{'slot': 1, 'type': {'name': 'grass', 'url': ...    NaN
# 35                                                     NaN    130
# 36                                                     NaN    NaN
# 37                                                     NaN    NaN
# 38                                                     NaN    NaN
# 39                                                     NaN    NaN
# 40                                                     NaN    NaN
# 41                                                     NaN    NaN
# 42                                                     NaN    NaN
# 43                                                     NaN    NaN
# 44                                                     NaN    NaN
# 45                                                     NaN    NaN
# 46                                                     NaN    NaN
# 47                                                     NaN    NaN
# 48                                                     NaN    NaN
# 49                                                     NaN    NaN

# %%
for listing in transposed_datad['abilities'] :
    transposed_datad['abilities'] = remove_URL(transposed_datad['abilities'][:])
    #transposed_datad['abilities'] = listing[:].replace(r'http\S+', '', regex = True)
transposed_datad.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 for listing in transposed_datad['abilities'] :
# ----> 2     transposed_datad['abilities'] = remove_URL(transposed_datad['abilities'][:])
#       3     #transposed_datad['abilities'] = listing[:].replace(r'http\S+', '', regex = True)
#       4 transposed_datad.head()
#
# Cell In[24], line 3, in remove_URL(text)
#       2 def remove_URL(text):
# ----> 3     return re.sub(r"'url ' : 'http\S+", "", text)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'Series'

# %%
transposed_datad['abilities'][0]
# Out:
# [{'ability': {'name': 'overgrow',
#    'url': 'https://pokeapi.co/api/v2/ability/65/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'chlorophyll',
#    'url': 'https://pokeapi.co/api/v2/ability/34/'},
#   'is_hidden': True,
#   'slot': 3}]

# %% [markdown]
# ### Building the model

# %%
X = df['description']
y = df['pokemon']
cv = CountVectorizer()
X = cv.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)

clf = MultinomialNB()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 4
#       2 y = df['pokemon']
#       3 cv = CountVectorizer()
# ----> 4 X = cv.fit_transform(X)
#       5 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)
#       7 clf = MultinomialNB()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:1388, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1380             warnings.warn(
#    1381                 "Upper case characters found in"
#    1382                 " vocabulary while 'lowercase'"
#    1383                 " is True. These entries will not"
#    1384                 " be matched with any documents"
#    1385             )
#    1386             break
# -> 1388 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1390 if self.binary:
#    1391     X.data.fill(1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:1275, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1273 for doc in raw_documents:
#    1274     feature_counter = {}
# -> 1275     for feature in analyze(doc):
#    1276         try:
#    1277             feature_idx = vocabulary[feature]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:111, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     109 else:
#     110     if preprocessor is not None:
# --> 111         doc = preprocessor(doc)
#     112     if tokenizer is not None:
#     113         doc = tokenizer(doc)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:69, in _preprocess(doc, accent_function, lower)
#      50 """Chain together an optional series of text preprocessing steps to
#      51 apply to a document.
#      52
#    (...)
#      66     preprocessed string
#      67 """
#      68 if lower:
# ---> 69     doc = doc.lower()
#      70 if accent_function is not None:
#      71     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# ### Create the app

# %%
app = Flask(_name_)

@app.route('/')
def home():
    return render_template('home.html')

@app.route('/predict', methods=['POST'])
def predict():
    cleaned_data
